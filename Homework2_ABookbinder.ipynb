# %% [markdown]
# <h1>Homework 2</h1>

# %% [markdown]
# #### Bayes' theorem:
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posterior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}

# %% [markdown]
# # Question 1
# ### Read the following example and complete the exercises
#
# You are at the age of 21 and curious about if drinking alcohol would cause liver disease. You contacted a clinic site and got the following information.
#
# 1. Past data tells you that 10% of patients entering the clinic have liver disease (**Prior**).
#
# 2. Five percent of the clinic’s patients are alcoholics (**Marginal Probability**).
#
# 3. Among the patients diagnosed with liver disease, 15% are alcoholics (**Likelihood**).
#
# Now you wonder what is the probability of a patient from the clinic have liver disease given that the patient is alcoholic (**Posterior**)

# %% [markdown]
# ### 1.1
#
# #### If A represents the event of being an alcoholic patient in the clinic and L represents the event of being a patient with liver disease in the clinic, write the bayesian representation (P(A|B)) in the following cells

# %% [markdown]
# Posterior = P(L|A) = P(A|L)*P(L)/P(A)

# %% [markdown]
# Prior = P(L) = 10%

# %% [markdown]
# Likelihood = P(A|L) = 15%

# %% [markdown]
# Marginal Probability = P(A) = 5%

# %% [markdown]
# ### 1.2
#
# #### Define all the information available and calculate the posterior probability

# %%
prior1 = 0.1
likelihood1 = .15
marginal_probability1 = 0.05
posterior1 = likelihood1*prior1/marginal_probability1
# Out:
# 0.3

# %% [markdown]
# # Question 2
# ### Read the following example and complete the exercises
# Shown by a <a href="https://pubmed.ncbi.nlm.nih.gov/34242764/#:~:text=The%20overall%20sensitivity%20of%20the,%25%20CI%2024.4%2D65.1">research study</a>, the rapid antigen test for Covid has a sensitivity of 65.3% and a specificity of 99.9%. Assume 1% people have Covid. If randomly select a person and he/she tests positive using the rapid antigen test, what is the probability the person has Covid (posterior).

# %% [markdown]
# ### 2.1
#
# #### The probability of which event is considered marginal probability in this case? Define it in the first cell below and calculate it in the second cell below

# %% [markdown]
# The event is: testing positive using a rapid antigen test.
#
# P(positive antigen) = P(positive antigen|covid)*P(covid)+P(positive antigen|~covid)*P(~covid)

# %%
p_covid = 0.01
TPR = 0.653
FPR = 0.999

marg_prob_q2 = TPR*p_covid+(1-FPR)*(1-p_covid)
# Out:
# 0.007520000000000001

# %% [markdown]
# ### 2.2
#
# #### Define all the information and calculate the probability the randomly selected person has Covid

# %% [markdown]
# P(COVID|positive antigen) = P(positive antigen|covid)*P(COVID)/P(positive antigen)

# %%
post_q2 = TPR*p_covid/marg_prob_q2
# Out:
# 0.8683510638297872

# %% [markdown]
# # Question 3
# ### <a href="https://juliastats.org/Distributions.jl/stable/starting/">This page</a> is the documentation for Distribution.jl and complete the exercies

# %% [markdown]
# ### 3.1
#
# #### Randomly draw 1000 samples from a normal distribution with mean = 5 and std = 2

# %%
import Pkg
Pkg.activate(".")
Pkg.add(["Distributions","Random","Plots"])
using Distributions, Random, Plots
# Out:
#   Activating project at `c:\Users\mrclo\Documents\JuliaScripts\BME-502-2025-homeworks`
#    Resolving package versions...
#   No Changes to `C:\Users\mrclo\Documents\JuliaScripts\BME-502-2025-homeworks\Project.toml`
#   No Changes to `C:\Users\mrclo\Documents\JuliaScripts\BME-502-2025-homeworks\Manifest.toml`

# %%
d = Normal(5,2)
data = rand(d,1000)
# Out:
# 1000-element Vector{Float64}:
#  3.840014111434049
#  4.2065016628753416
#  4.758308885162334
#  4.004788142123084
#  6.2383647349277425
#  3.5184078603036237
#  5.919061671064457
#  2.167315146704377
#  7.698305630793195
#  5.3124626499048695
#  ⋮
#  4.3564643896013004
#  8.172815219328317
#  5.014971623413403
#  6.978488573702412
#  7.54274684574907
#  5.588481978743795
#  1.3250460064239817
#  3.3205835791078964
#  4.602696349433492

# %% [markdown]
# ### 3.2
#
# #### Plot  the distribution above in a histogram

# %%
histogram(data)

# %% [markdown]
# ### 3.3
#
# #### Plot  the same distribution and change the bins to 50

# %%
histogram(data,bins=range(minimum(data),maximum(data),length=51))

# %% [markdown]
# ### 3.4
#
# #### Choose a distribution other than normal distribution, Describe what it represents, and draw 1000 samples from the distribution and plot it using parameters of your choice

# %% [markdown]
# Which distribution do you pick: Poisson distribution

# %% [markdown]
# What does the distribution represent? Number of independent events occuring in a fixed time interval.

# %%
d2 = Poisson(4)
data2 = rand(d2,1000)
# Out:
# 1000-element Vector{Int64}:
#  5
#  5
#  1
#  5
#  1
#  3
#  9
#  3
#  4
#  1
#  ⋮
#  4
#  1
#  5
#  9
#  3
#  5
#  5
#  6
#  8

# %% [markdown]
# ### 3.5
#
# #### Plot  the two distributions in the same plot

# %%
bins2 = range(0,10,length=11)
# histogram(data,bins=bins2)
# histogram(data2,bins=bins2)
histogram(Any[data, data2], 
# line=(3,0.2,:green), 
fillcolor=[:red :blue], 
fillalpha=0.2,
bins=bins2)

# %% [markdown]
# ### 3.6
#
# #### Draw 10000 samples from the two distributions separately and plot them in the same plot

# %%
data3 = rand(d,10000)
data4 = rand(d2,10000)

bins2 = range(0,10,length=11)
# histogram(data,bins=bins2)
# histogram(data2,bins=bins2)
histogram(Any[data3,data4], 
# line=(3,0.2,:green), 
fillcolor=[:red :blue], 
fillalpha=0.2,
bins=bins2)
