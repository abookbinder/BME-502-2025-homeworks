# %% [markdown]
# <h1>Homework 3</h1>

# %% [markdown]
# # Question 1
# ### (Bayes Theorem) Read the following example and complete the exercises
#
# Trolls Under the Bridge
# 1. Trolls(T) are bad
# 2. Gnomes(G) are benign
# 3. Every bridge has 5 creatures under it
#
# Below are the probabilities of what creatures live under a bridge:
# 1. TTGGG: 25% (E1)
# 2. TGGGG: 25% (E2)
# 3. GGGGG: 50% (E3)
#
# A knight is approaching a bridge and he wants to know his chance of crossing the bridge safely.

# %% [markdown]
# ### 1.1
#
# #### What is the chance of the knight crossing the bridge safely?

# %%
P_E1 = 0.25
P_troll_E1 = 2/5
P_E2 = 0.25
P_troll_E2 = 1/5
P_E3 = 0.5
P_troll_E3 = 0
p_safe_unknown = 1.0 - (P_E1*(P_troll_E1>0) + P_E2*(P_troll_E2>0))
# Out:
# 0.5

# %% [markdown]
# ### 1.2
#
# #### Before crossing a bridge, a knight captures a troll. “I now have an 75% chance of crossing safely,” he reasons, “since only the case 25% had TTGGG (E1) now have TGGG is still a threat.”
#
# #### Do you agree with him? Why?

# %% [markdown]
# I do not agree with him, because by catching a troll, he knows that the bridge is either E1 or E2, and he is only safe if the bridge is E2, giving him a different chance of safety.

# %% [markdown]
# ### 1.3
#
# #### Now he wants to use Bayes' theorem to calculate his chance of crossing safely given a troll captured
#
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posteior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}
#
# #### Given the three events, E1, E2, and E3, which two of the three events does the knight need to consider after a troll was captured?

# %% [markdown]
# After capturing a troll, he only needs to consider events E1 and E2, as E3 has no trolls.

# %% [markdown]
# ### 1.4
#
# #### Use Bayes' theorem to calculate the probability of the two events in 1.3 (separately) given the troll was captured.

# %% [markdown]
# Probability of one event given a troll captured:

# %%
P_troll = sum([P_E1,P_E2,P_E3].*[P_troll_E1,P_troll_E2,P_troll_E3])
P_E1_troll = P_troll_E1*P_E1/P_troll
# Out:
# 0.6666666666666666

# %% [markdown]
# Probability of the other event given a troll captured:

# %%
P_E2_troll = P_troll_E2*P_E2/P_troll
# Out:
# 0.3333333333333333

# %% [markdown]
# ### 1.5
#
# #### What is the chance of the knight crossing safely?

# %%
P_safety = P_E2_troll
# Out:
# 0.3333333333333333

# %% [markdown]
# #### Now looking back to 1.1, the probabilities were changed after assimilating data!

# %% [markdown]
# # Question 2
# ### (Polynomial Fitting) Read the following example and complete the exercises
#
# Biological data always comes with errors that influence the intepretation of the data significantly. In this question, we will simulate data and see how noises affect the parameter estimation.

# %%
import Pkg
Pkg.activate(".")
Pkg.add(["Distributions", "Plots", "Polynomials", "Random"])
# Out:
#   Activating project at `C:\Users\Alex\Documents\JuliaNotebooks\BME-502-2025-homeworks`
#     Updating registry at `C:\Users\Alex\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed LERC_jll ───────────────────────── v4.0.1+0
#    Installed libfdk_aac_jll ─────────────────── v2.0.3+0
#    Installed libdecor_jll ───────────────────── v0.2.2+0
#    Installed x265_jll ───────────────────────── v3.5.0+0
#    Installed Libmount_jll ───────────────────── v2.40.3+0
#    Installed GR_jll ─────────────────────────── v0.73.13+0
#    Installed JpegTurbo_jll ──────────────────── v3.1.1+0
#    Installed HypergeometricFunctions ────────── v0.3.27
#    Installed Opus_jll ───────────────────────── v1.3.3+0
#    Installed RelocatableFolders ─────────────── v1.0.1
#    Installed StatsFuns ──────────────────────── v1.3.2
#    Installed Xorg_xkbcomp_jll ───────────────── v1.4.6+1
#    Installed Accessors ──────────────────────── v0.1.41
# ...

# %%
using Distributions
using Plots
using Polynomials
using Random

# %% [markdown]
# ### 2.1
#
# 1. Generate the independent variable x ranging from -10 to 10 with an increment of 1
# 2. Generate the dependent variable y_true using the equation y_true = x^2 + 4x - 2

# %%
x = -10:1:10
true_poly = Polynomial([-2,4,1])
y_true = true_poly.(x)
# Out:
# 21-element Vector{Int64}:
#   58
#   43
#   30
#   19
#   10
#    3
#   -2
#   -5
#   -6
#   -5
#   -2
#    3
#   10
#   19
#   30
#   43
#   58
#   75
#   94
#  115
#  138

# %% [markdown]
# ### 2.2
#
# 1. Generate the Guassian noises with zero mean and a standard deviation of 10
#
# 2. Add the noises to y_true to obtain y_observed

# %%
d = Normal(0,10)
noise = rand(d,length(x))
y_observed = y_true+noise
# Out:
# 21-element Vector{Float64}:
#   61.75591571087759
#   51.584469545746366
#   25.012916408231703
#   25.868676511251394
#   -1.6297398715087859
#   17.139116061723946
#    8.897675730536118
#  -16.941068808909336
#    0.16393692031360274
#    5.51698372505453
#    9.629756313243195
#   -1.203274730008169
#    3.051637024850166
#   21.796338513247978
#   39.76699653900614
#   34.783546635363564
#   54.475369008279564
#   75.78781728129574
#  103.67931934331489
#  117.01331647410692
#  160.65486301410402

# %% [markdown]
# ### 2.3
#
# #### Fit the data (x, y_observed) with a second order polynomial.
#
# 1. Make a scatter plot of y_observed along x
# 2. Plot a line of y_true along x on the scatter plot
# 3. Plot a line of the fitted polynomial along x on the same plot

# %%
y_fit = Polynomials.fit(x,y_observed,2)
scatter(x,y_observed,label="Observed")
plot!(x,y_true,label="True")
plot!(x,y_fit.(x),label="Fit")

# %% [markdown]
# ### 2.4
#
# 1. Repeat 2.2 and 2.3 with a noise with a standard deviation of 40

# %%
d2 = Normal(0,40)
noise2 = rand(d2,length(x))
y_observed2 = y_true+noise2
y_fit2 = Polynomials.fit(x,y_observed2,2)
scatter(x,y_observed2,label="Observed")
plot!(x,y_true,label="True")
plot!(x,y_fit2.(x),label="Fit")

# %% [markdown]
# 2. Compare the plot with the plot in 2.3. Is the fit closer to y_true or not, and why?

# %% [markdown]
# The fit is much futher from y_true in 2.4 compared to 2.3. This is because the standard deviation is high enough that the shape of the curve is lost in the noise, resulting in a drastically different best fit line.

# %% [markdown]
# ### 2.5
#
# #### Repeat 2.2 and 2.3 with a tenth order polynomial fit

# %%
y_fit3 = Polynomials.fit(x,y_observed,10)
scatter(x,y_observed,label="Observed")
plot!(x,y_true,label="True")
plot!(x,y_fit3.(x),label="Fit")

# %% [markdown]
# ### 2.6
#
# 1. Create a new independent parameter x_fit ranging from -11 to 11 with an increment of 0.2
# 2. Plot the same three plots as in 2.3 again but apply the tenth order polynomial to x_fit instead of x

# %%
x_fit = -11:0.2:11
scatter(x,y_observed,label="Observed")
plot!(x,y_true,label="True")
plot!(x_fit,y_fit3.(x_fit),label="Fit")

# %% [markdown]
# 3. What do you observe in the plot? What is this phenomenon called?

# %% [markdown]
# The curve sharply drops off beyond the lowest point, and also sharply rises after the last point, due to the higher order terms. This phenomenon is called overfitting.
